# %% [markdown]
# # Libraries

# %%
import networkx as nx
import matplotlib.pyplot as plt 
import random

# %% [markdown]
# # Graph

# %%
def get_default_graph():
    G = nx.Graph()

    G.add_node("1")
    G.add_node("2")
    G.add_node("3")
    G.add_node("4")
    G.add_node("5")
    G.add_node("6")
    G.add_node("7")

    G.add_edge("1", "2", weight=12)
    G.add_edge("1", "3", weight=10)
    G.add_edge("1", "7", weight=12)
    G.add_edge("2", "3", weight=8)
    G.add_edge("2", "4", weight=12)
    G.add_edge("3", "4", weight=11)
    G.add_edge("3", "5", weight=3)
    G.add_edge("3", "7", weight=9)
    G.add_edge("4", "5", weight=11)
    G.add_edge("4", "6", weight=10)
    G.add_edge("5", "6", weight=6)
    G.add_edge("5", "7", weight=7)
    G.add_edge("6", "7", weight=9)
    
    return G

def plot_graph(Graph):
    random.seed(0)
    pos = nx.spring_layout(Graph, seed=0)

    # Create a smaller figure size
    plt.figure(figsize=(4, 3))  # Adjust the width and height as needed

    # Draw nodes
    nx.draw(Graph, pos, with_labels=True, node_color='lightblue', edge_color='gray', font_weight='bold', node_size=1000)

    # Draw edge labels with weights
    edge_labels = {(u, v): d['weight'] for u, v, d in Graph.edges(data=True)}
    nx.draw_networkx_edge_labels(Graph, pos, edge_labels=edge_labels)

    plt.show()

# %% [markdown]
# # Algorithms

# %%
G = get_default_graph()
plot_graph(G)

# %%
def genetic():
    return 0
